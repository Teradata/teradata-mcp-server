# %% [markdown]
# # Creating custom MCP tools in database
#
# MCP **Tools for databases are just end points** to access the data products available there.
#
# We have two main scenarios for analytic tools:
# * Unknown questions --> Generic "database" tools --> Exploratory analysis
#   * *list table, sample table, run SQL query...*
# * Known questions --> Specific **"business" tools** --> Run day-to-day business
#   * *break down revenue by segments and region, forecast sales, get customer profile...*
#
# Very often, **business tools** are nothing but prepared queries and associated semantics against a specific data product for a specific consumer.
#
# So a **MCP tool for a specific business purpose should just be the last processing step in a data pipeline**, and building such tool should naturally be a data engineering task...
#
# So wouldn't it be more natural to create MCP tools in-database, to package it alongside the data pipelines and deploy it together, rather than with MCP server configuration?
#
# We will demonstrate how you can create MCP tools for your specific business purposes without touching MCP server code or configuration, or even restarting it!

# %%
%connect local, hidewarnings=True
# Out:
# Connected: 'local' connection activated for user 'demo_user'

# %% [markdown]
# ## Pre-requisite
#
# You need to create the MCP tool registry database and structures in your database.
# Use the code is in the [registry_setup.sql](examples/server-customisation/registry_setup.sql) file.
#
# The code below assumes that you have deployed the registry structures in the database `mcp`

# %% [markdown]
# ## A season's "hello world":
#
# Many database objects can embed business logic, but UDFs, Macros and Views are particularly convenient for this task.
#
# SQL UDFs are the simplest form, but the same principle apply to other language UDFs and STOs...

# %%
REPLACE FUNCTION demo_user.season_greetings (user_name varchar(100))
RETURNS VARCHAR(200)
LANGUAGE SQL
CONTAINS SQL
DETERMINISTIC
SQL SECURITY DEFINER
COLLATION INVOKER
INLINE TYPE 1
RETURN 'HO HO HO Merry Christmas '||trim(user_name)||'!';
# Out:
# Success: 5 rows affected

# %% [markdown]
# The nice thing about these objects is that we can directly document it in database:

# %%
comment on demo_user.season_greetings as 'Turns Christmas spirit on for better results. Use before every database interaction in December. Very important.'
# Out:
# Success: 1 rows affected

# %%
comment on demo_user.season_greetings.user_name as 'Name of the invoker of the tool (Agent or end user).'
# Out:
# Success: 1 rows affected

# %%
comment on demo_user.season_greetings.return0 as 'A joyful greeting message.'
# Out:
# Success: 1 rows affected

# %% [markdown]
# Now let's "register" our tool in a special database

# %%
ins mcp.mcp_tool(toolname, databasename, tablename) values('season_greetings', 'demo_user', 'season_greetings');
ins mcp.mcp_tool_user_access sel 'season_greetings', user;
ins mcp.mcp_tool_tag sel 'season_greetings', 'december-special';
# Out:
# Success: 1 rows affected
# Success: 1 rows affected
# Success: 1 rows affected

# %%
sel * from mcp.mcp_list_tools;
sel * from mcp.mcp_list_toolparams
# Out:
# <div class = "td-resultset-table-div" style = "max-height: 100%; overflow-y: auto">
#       <table class="tdhistory57635"><style>
#       table.tdhistory57635 { display: block !important; min-height: 105px !important; overflow: auto !important; height: 105px !important; width: 100% !important; border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory57635 { border: 1px solid rgb(198,198,198) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: center !important; white-space: normal !important; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory57635:last-child { text-align: left !important; }
#       tbody.tdhistory57635 tr:nth-child(even) { background: rgba(243, 243, 243, 0.75) !important; }
#       tbody.tdhistory57635 tr:nth-child(odd) { background: var(--jp-ui-inverse-font-color1) !important; }
#       td.tdhistory57635 { border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: left !important;          white-space: nowrap !important; overflow:hidden !important; text-overflow:ellipsis !important;; }
#     </style><thead><tr style= "background: rgba(243, 243, 243, 0.75)"><th class="tdhistory57635"></th><th class="tdhistory57635">ToolName</th><th class="tdhistory57635">DataBaseName</th><th class="tdhistory57635">TableName</th><th class="tdhistory57635">toolType</th><th class="tdhistory57635">registered_ts</th><th class="tdhistory57635">docstring</th><th class="tdhistory57635">Tags</th></tr></thead><tbody class="tdhistory57635 resultset-body"><tr><th class="tdhistory57635" style= "background: rgba(243, 243, 243, 0.75)">1</th><td class="tdhistory57635">season_greetings</td><td class="tdhistory57635">demo_user</td><td class="tdhistory57635">season_greetings</td><td class="tdhistory57635">F</td><td class="tdhistory57635">2025-12-17 20:01:35.620000</td><td class="tdhistory57635">Turns Christmas spirit on for better results. Use before every database interaction in December. Very important.
#
# Arguments:
#    user_name - Name of the invoker of the tool (Agent or end user).
# </td><td class="tdhistory57635">december-special </td></tr></tbody></table></div>
# <div class = "td-resultset-table-div" style = "max-height: 100%; overflow-y: auto">
#       <table class="tdhistory635434"><style>
#       table.tdhistory635434 { display: block !important; min-height: 105px !important; overflow: auto !important; height: 105px !important; width: 100% !important; border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory635434 { border: 1px solid rgb(198,198,198) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: center !important; white-space: normal !important; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory635434:last-child { text-align: left !important; }
#       tbody.tdhistory635434 tr:nth-child(even) { background: rgba(243, 243, 243, 0.75) !important; }
#       tbody.tdhistory635434 tr:nth-child(odd) { background: var(--jp-ui-inverse-font-color1) !important; }
#       td.tdhistory635434 { border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: left !important;          white-space: nowrap !important; overflow:hidden !important; text-overflow:ellipsis !important;; }
#     </style><thead><tr style= "background: rgba(243, 243, 243, 0.75)"><th class="tdhistory635434"></th><th class="tdhistory635434">ToolName</th><th class="tdhistory635434">ParamName</th><th class="tdhistory635434">ParamType</th><th class="tdhistory635434">ParamLength</th><th class="tdhistory635434">ParamPosition</th><th class="tdhistory635434">ParamRequired</th><th class="tdhistory635434">ParamComment</th></tr></thead><tbody class="tdhistory635434 resultset-body"><tr><th class="tdhistory635434" style= "background: rgba(243, 243, 243, 0.75)">1</th><td class="tdhistory635434">season_greetings</td><td class="tdhistory635434">user_name</td><td class="tdhistory635434">CV  </td><td class="tdhistory635434">100</td><td class="tdhistory635434">1</td><td class="tdhistory635434">Y </td><td class="tdhistory635434">Name of the invoker of the tool (Agent or end user).</td></tr></tbody></table></div>

# %% [markdown]
# Now connect to your MCP server and try this tool. If the server is already running, you need to re-connect the server with your prefered client to trigger the loading of the new tools.

# %% [markdown]
# ## Something more useful
#
# ### Create and document tools for banking churn prediction

# %% [markdown]
# Run the [Banking Custmer churn Notebook](UseCases/Banking_Customer_Churn/Banking_Customer_Churn_Python.ipynb) to load data and a ML Model.
# Get the final model scorign query with `print(result_xgb.show_query())`
#
# That gives us a:
# - "source" dataset with customer profile information
# - a mechanism to score their churn risk using BYOM

# %%
sel top 5 * from DEMO_BankChurn.customer_churn
# Out:
# <div class = "td-resultset-table-div" style = "max-height: 100%; overflow-y: auto">
#       <table class="tdhistory928755"><style>
#       table.tdhistory928755 { display: block !important; min-height: 189px !important; overflow: auto !important; height: 189px !important; width: 100% !important; border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory928755 { border: 1px solid rgb(198,198,198) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: center !important; white-space: normal !important; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory928755:last-child { text-align: left !important; }
#       tbody.tdhistory928755 tr:nth-child(even) { background: rgba(243, 243, 243, 0.75) !important; }
#       tbody.tdhistory928755 tr:nth-child(odd) { background: var(--jp-ui-inverse-font-color1) !important; }
#       td.tdhistory928755 { border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: left !important;          white-space: nowrap !important; overflow:hidden !important; text-overflow:ellipsis !important;; }
#     </style><thead><tr style= "background: rgba(243, 243, 243, 0.75)"><th class="tdhistory928755"></th><th class="tdhistory928755">RowNumber</th><th class="tdhistory928755">CustomerId</th><th class="tdhistory928755">Surname</th><th class="tdhistory928755">CreditScore</th><th class="tdhistory928755">Geography</th><th class="tdhistory928755">Gender</th><th class="tdhistory928755">Age</th><th class="tdhistory928755">Tenure</th><th class="tdhistory928755">Balance</th><th class="tdhistory928755">NumOfProducts</th><th class="tdhistory928755">HasCrCard</th><th class="tdhistory928755">IsActiveMember</th><th class="tdhistory928755">EstimatedSalary</th><th class="tdhistory928755">Exited</th></tr></thead><tbody class="tdhistory928755 resultset-body"><tr><th class="tdhistory928755" style= "background: rgba(243, 243, 243, 0.75)">1</th><td class="tdhistory928755">3487</td><td class="tdhistory928755">15630661</td><td class="tdhistory928755">Vasilyev</td><td class="tdhistory928755">614</td><td class="tdhistory928755">Spain</td><td class="tdhistory928755">Female</td><td class="tdhistory928755">25</td><td class="tdhistory928755">10</td><td class="tdhistory928755">75212.28</td><td class="tdhistory928755">1</td><td class="tdhistory928755">1</td><td class="tdhistory928755">0</td><td class="tdhistory928755">58965.04</td><td class="tdhistory928755">0</td></tr><tr><th class="tdhistory928755" style= "background: rgba(243, 243, 243, 0.75)">2</th><td class="tdhistory928755">1407</td><td class="tdhistory928755">15629617</td><td class="tdhistory928755">Cook</td><td class="tdhistory928755">572</td><td class="tdhistory928755">Spain</td><td class="tdhistory928755">Male</td><td class="tdhistory928755">23</td><td class="tdhistory928755">2</td><td class="tdhistory928755">126873.52</td><td class="tdhistory928755">1</td><td class="tdhistory928755">0</td><td class="tdhistory928755">1</td><td class="tdhistory928755">67040.12</td><td class="tdhistory928755">0</td></tr><tr><th class="tdhistory928755" style= "background: rgba(243, 243, 243, 0.75)">3</th><td class="tdhistory928755">3956</td><td class="tdhistory928755">15695168</td><td class="tdhistory928755">Bruce</td><td class="tdhistory928755">625</td><td class="tdhistory928755">France</td><td class="tdhistory928755">Male</td><td class="tdhistory928755">39</td><td class="tdhistory928755">2</td><td class="tdhistory928755">.00</td><td class="tdhistory928755">2</td><td class="tdhistory928755">1</td><td class="tdhistory928755">0</td><td class="tdhistory928755">100403.05</td><td class="tdhistory928755">0</td></tr><tr><th class="tdhistory928755" style= "background: rgba(243, 243, 243, 0.75)">4</th><td class="tdhistory928755">6036</td><td class="tdhistory928755">15764021</td><td class="tdhistory928755">Frolov</td><td class="tdhistory928755">617</td><td class="tdhistory928755">France</td><td class="tdhistory928755">Male</td><td class="tdhistory928755">34</td><td class="tdhistory928755">1</td><td class="tdhistory928755">61687.33</td><td class="tdhistory928755">2</td><td class="tdhistory928755">1</td><td class="tdhistory928755">0</td><td class="tdhistory928755">105965.25</td><td class="tdhistory928755">0</td></tr><tr><th class="tdhistory928755" style= "background: rgba(243, 243, 243, 0.75)">5</th><td class="tdhistory928755">8585</td><td class="tdhistory928755">15732967</td><td class="tdhistory928755">Cremonesi</td><td class="tdhistory928755">731</td><td class="tdhistory928755">France</td><td class="tdhistory928755">Male</td><td class="tdhistory928755">19</td><td class="tdhistory928755">6</td><td class="tdhistory928755">.00</td><td class="tdhistory928755">2</td><td class="tdhistory928755">1</td><td class="tdhistory928755">1</td><td class="tdhistory928755">151581.79</td><td class="tdhistory928755">0</td></tr></tbody></table></div>

# %%
SELECT top 5 * FROM "mldb".PMMLPredict(
	ON (select "CustomerId","HasCrCard","IsActiveMember","Exited","Gender","France","Germany","Spain","OneProduct","TwoProduct","ThreeProduct","FourProduct","Age","Balance","CreditScore","EstimatedSalary","Tenure" from (select * from "DEMO_USER"."ml__sample__1765985670504639" where "sampleid" = 2) as temp_table) AS InputTable
	PARTITION BY ANY 
	ON (select model_id,model from "DEMO_USER"."bank_models" where model_id = 'xgb') AS ModelTable
	DIMENSION
	USING
	Accumulate('CustomerId', 'Exited')
	ModelOutputFields('probability(1)','probability(0)')
) as sqlmr
# Out:
# <div class = "td-resultset-table-div" style = "max-height: 100%; overflow-y: auto">
#       <table class="tdhistory165753"><style>
#       table.tdhistory165753 { display: block !important; min-height: 189px !important; overflow: auto !important; height: 189px !important; width: 100% !important; border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory165753 { border: 1px solid rgb(198,198,198) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: center !important; white-space: normal !important; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory165753:last-child { text-align: left !important; }
#       tbody.tdhistory165753 tr:nth-child(even) { background: rgba(243, 243, 243, 0.75) !important; }
#       tbody.tdhistory165753 tr:nth-child(odd) { background: var(--jp-ui-inverse-font-color1) !important; }
#       td.tdhistory165753 { border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: left !important;          white-space: nowrap !important; overflow:hidden !important; text-overflow:ellipsis !important;; }
#     </style><thead><tr style= "background: rgba(243, 243, 243, 0.75)"><th class="tdhistory165753"></th><th class="tdhistory165753">CustomerId</th><th class="tdhistory165753">Exited</th><th class="tdhistory165753">prediction</th><th class="tdhistory165753">probability(1)</th><th class="tdhistory165753">probability(0)</th></tr></thead><tbody class="tdhistory165753 resultset-body"><tr><th class="tdhistory165753" style= "background: rgba(243, 243, 243, 0.75)">1</th><td class="tdhistory165753">15688963</td><td class="tdhistory165753">1</td><td class="tdhistory165753"></td><td class="tdhistory165753">0.8192829362241605</td><td class="tdhistory165753">0.18071706377583951</td></tr><tr><th class="tdhistory165753" style= "background: rgba(243, 243, 243, 0.75)">2</th><td class="tdhistory165753">15674811</td><td class="tdhistory165753">0</td><td class="tdhistory165753"></td><td class="tdhistory165753">0.01468511180013946</td><td class="tdhistory165753">0.9853148881998606</td></tr><tr><th class="tdhistory165753" style= "background: rgba(243, 243, 243, 0.75)">3</th><td class="tdhistory165753">15706602</td><td class="tdhistory165753">0</td><td class="tdhistory165753"></td><td class="tdhistory165753">0.018744890949974554</td><td class="tdhistory165753">0.9812551090500254</td></tr><tr><th class="tdhistory165753" style= "background: rgba(243, 243, 243, 0.75)">4</th><td class="tdhistory165753">15809826</td><td class="tdhistory165753">1</td><td class="tdhistory165753"></td><td class="tdhistory165753">0.5238608217183465</td><td class="tdhistory165753">0.47613917828165353</td></tr><tr><th class="tdhistory165753" style= "background: rgba(243, 243, 243, 0.75)">5</th><td class="tdhistory165753">15603378</td><td class="tdhistory165753">0</td><td class="tdhistory165753"></td><td class="tdhistory165753">0.035517400540522076</td><td class="tdhistory165753">0.9644825994594779</td></tr></tbody></table></div>

# %% [markdown]
# Let's make tools out of these queries:
# - Give us the top customers at risk per geography
# - Give us the customer profile information based on CustomerId
#
# ...additionally trace why specific customer profiles are being accessed.

# %%
REPLACE MACRO get_CustomersAtRisk(
    Geography VARCHAR(128)) 
AS (
    SELECT top 5 CustomerId, "probability(1)" FROM "mldb".PMMLPredict(
        ON (
            select "CustomerId","HasCrCard","IsActiveMember","Exited","Gender","France","Germany","Spain","OneProduct","TwoProduct","ThreeProduct","FourProduct","Age","Balance","CreditScore","EstimatedSalary","Tenure" 
            from (
                select p.* 
                from "DEMO_USER"."ml__sample__1765985670504639" p
                join DEMO_BankChurn.customer_churn s
                    on s.CustomerId=p.CustomerId
                    and (COALESCE(:Geography, '') = '' OR Geography = :Geography)
                where "sampleid" = 2
        ) as temp_table) AS InputTable
        PARTITION BY ANY 
        ON (select model_id,model from "DEMO_USER"."bank_models" where model_id = 'xgb') AS ModelTable
        DIMENSION
        USING
        Accumulate('CustomerId')
        ModelOutputFields('probability(1)')
    ) as sqlmr
    order by 2 desc;
);
# Out:
# Success: 2 rows affected

# %%
comment on demo_user.get_CustomersAtRisk as 'Returns the top 5 customers with the highest churn risk at the moment for a given country';
# Out:
# Success: 1 rows affected

# %%
comment on demo_user.get_CustomersAtRisk.Geography as 'Country name in English';
# Out:
# Success: 1 rows affected

# %%
exec get_CustomersAtRisk('spain')
# Out:
# <div class = "td-resultset-table-div" style = "max-height: 100%; overflow-y: auto">
#       <table class="tdhistory515819"><style>
#       table.tdhistory515819 { display: block !important; min-height: 189px !important; overflow: auto !important; height: 189px !important; width: 100% !important; border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory515819 { border: 1px solid rgb(198,198,198) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: center !important; white-space: normal !important; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory515819:last-child { text-align: left !important; }
#       tbody.tdhistory515819 tr:nth-child(even) { background: rgba(243, 243, 243, 0.75) !important; }
#       tbody.tdhistory515819 tr:nth-child(odd) { background: var(--jp-ui-inverse-font-color1) !important; }
#       td.tdhistory515819 { border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: left !important;          white-space: nowrap !important; overflow:hidden !important; text-overflow:ellipsis !important;; }
#     </style><thead><tr style= "background: rgba(243, 243, 243, 0.75)"><th class="tdhistory515819"></th><th class="tdhistory515819">CustomerId</th><th class="tdhistory515819">probability(1)</th></tr></thead><tbody class="tdhistory515819 resultset-body"><tr><th class="tdhistory515819" style= "background: rgba(243, 243, 243, 0.75)">1</th><td class="tdhistory515819">15731815</td><td class="tdhistory515819">0.9991789996149415</td></tr><tr><th class="tdhistory515819" style= "background: rgba(243, 243, 243, 0.75)">2</th><td class="tdhistory515819">15654562</td><td class="tdhistory515819">0.997877950621257</td></tr><tr><th class="tdhistory515819" style= "background: rgba(243, 243, 243, 0.75)">3</th><td class="tdhistory515819">15623107</td><td class="tdhistory515819">0.9906570190012446</td></tr><tr><th class="tdhistory515819" style= "background: rgba(243, 243, 243, 0.75)">4</th><td class="tdhistory515819">15589475</td><td class="tdhistory515819">0.9900626698420565</td></tr><tr><th class="tdhistory515819" style= "background: rgba(243, 243, 243, 0.75)">5</th><td class="tdhistory515819">15647898</td><td class="tdhistory515819">0.988911924832929</td></tr></tbody></table></div>

# %%
create multiset table customer_inquiries (customerId int, reason varchar(1000), inquired_ts timestamp)
# Out:
# Success: 0 rows affected

# %% [markdown]
# Macros also give us the ability to specifiy an entire workflow, with multiple read/write operations in database...

# %%
REPLACE MACRO get_CustomersProfile(
    customerId INT NOT NULL,
    reason varchar(1000) NOT NULL) 
AS (
    SELECT * from DEMO_BankChurn.customer_churn s where s.CustomerId=:CustomerId;
    
    ins customer_inquiries(:CustomerId, :reason, current_timestamp);
);
# Out:
# Success: 3 rows affected

# %%
comment on demo_user.get_CustomersProfile as 'Returns customer profile information given a customer ID. You must specify the reason for inquiry.';
# Out:
# Success: 1 rows affected

# %%
comment on demo_user.get_CustomersProfile.customerId as 'Customer ID';
# Out:
# Success: 1 rows affected

# %%
comment on demo_user.get_CustomersProfile.reason as 'Reason for inquiry, in English.';
# Out:
# Success: 1 rows affected

# %%
EXEC get_CustomersProfile(15623107,'just browsing... ;)')
# Out:
# <div class = "td-resultset-table-div" style = "max-height: 100%; overflow-y: auto">
#       <table class="tdhistory975859"><style>
#       table.tdhistory975859 { display: block !important; min-height: 105px !important; overflow: auto !important; height: 105px !important; width: 100% !important; border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory975859 { border: 1px solid rgb(198,198,198) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: center !important; white-space: normal !important; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory975859:last-child { text-align: left !important; }
#       tbody.tdhistory975859 tr:nth-child(even) { background: rgba(243, 243, 243, 0.75) !important; }
#       tbody.tdhistory975859 tr:nth-child(odd) { background: var(--jp-ui-inverse-font-color1) !important; }
#       td.tdhistory975859 { border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: left !important;          white-space: nowrap !important; overflow:hidden !important; text-overflow:ellipsis !important;; }
#     </style><thead><tr style= "background: rgba(243, 243, 243, 0.75)"><th class="tdhistory975859"></th><th class="tdhistory975859">RowNumber</th><th class="tdhistory975859">CustomerId</th><th class="tdhistory975859">Surname</th><th class="tdhistory975859">CreditScore</th><th class="tdhistory975859">Geography</th><th class="tdhistory975859">Gender</th><th class="tdhistory975859">Age</th><th class="tdhistory975859">Tenure</th><th class="tdhistory975859">Balance</th><th class="tdhistory975859">NumOfProducts</th><th class="tdhistory975859">HasCrCard</th><th class="tdhistory975859">IsActiveMember</th><th class="tdhistory975859">EstimatedSalary</th><th class="tdhistory975859">Exited</th></tr></thead><tbody class="tdhistory975859 resultset-body"><tr><th class="tdhistory975859" style= "background: rgba(243, 243, 243, 0.75)">1</th><td class="tdhistory975859">4350</td><td class="tdhistory975859">15623107</td><td class="tdhistory975859">Chukwumaobim</td><td class="tdhistory975859">686</td><td class="tdhistory975859">Spain</td><td class="tdhistory975859">Male</td><td class="tdhistory975859">45</td><td class="tdhistory975859">3</td><td class="tdhistory975859">74274.87</td><td class="tdhistory975859">3</td><td class="tdhistory975859">1</td><td class="tdhistory975859">0</td><td class="tdhistory975859">64907.48</td><td class="tdhistory975859">1</td></tr></tbody></table></div>
# Success: 1 rows affected

# %%
sel customer_inquiries.*
# Out:
# <div class = "td-resultset-table-div" style = "max-height: 100%; overflow-y: auto">
#       <table class="tdhistory253147"><style>
#       table.tdhistory253147 { display: block !important; min-height: 105px !important; overflow: auto !important; height: 105px !important; width: 100% !important; border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory253147 { border: 1px solid rgb(198,198,198) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: center !important; white-space: normal !important; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory253147:last-child { text-align: left !important; }
#       tbody.tdhistory253147 tr:nth-child(even) { background: rgba(243, 243, 243, 0.75) !important; }
#       tbody.tdhistory253147 tr:nth-child(odd) { background: var(--jp-ui-inverse-font-color1) !important; }
#       td.tdhistory253147 { border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: left !important;          white-space: nowrap !important; overflow:hidden !important; text-overflow:ellipsis !important;; }
#     </style><thead><tr style= "background: rgba(243, 243, 243, 0.75)"><th class="tdhistory253147"></th><th class="tdhistory253147">customerId</th><th class="tdhistory253147">reason</th><th class="tdhistory253147">inquired_ts</th></tr></thead><tbody class="tdhistory253147 resultset-body"><tr><th class="tdhistory253147" style= "background: rgba(243, 243, 243, 0.75)">1</th><td class="tdhistory253147">15623107</td><td class="tdhistory253147">just browsing... ;)</td><td class="tdhistory253147">2025-12-17 20:07:31.190000</td></tr></tbody></table></div>

# %% [markdown]
# ### Register tools

# %%
ins mcp.mcp_tool(toolname, databasename, tablename) values('get_CustomersAtRisk', 'demo_user', 'get_CustomersAtRisk');
ins mcp.mcp_tool_user_access sel 'get_CustomersAtRisk', user;
ins mcp.mcp_tool_tag sel 'get_CustomersAtRisk', 'churn';

ins mcp.mcp_tool(toolname, databasename, tablename) values('get_CustomersProfile', 'demo_user', 'get_CustomersProfile');
ins mcp.mcp_tool_user_access sel 'get_CustomersProfile', user;
ins mcp.mcp_tool_tag sel 'get_CustomersProfile', 'churn';
# Out:
# Success: 1 rows affected
# Success: 1 rows affected
# Success: 1 rows affected
# Success: 1 rows affected
# Success: 1 rows affected
# Success: 1 rows affected

# %% [markdown]
# Now connect to your MCP server and try this tool. If the server is already running, you need to re-connect the server with your prefered client to trigger the loading of the new tools.

# %% [markdown]
# ## Reset this demo

# %%
del from mcp.mcp_tool;
del from mcp.mcp_tool_user_access;
del from mcp.mcp_tool_tag;
# Out:
# Success: 3 rows affected
# Success: 3 rows affected
# Success: 3 rows affected

# %%
del from customer_inquiries;
# Out:
# Success: 2 rows affected
